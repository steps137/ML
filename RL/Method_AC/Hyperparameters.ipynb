# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# On-line, по одной
# 720 rew:  -99.9 ± 0.0 [-99.90,-99.72], best:  -2.94, ticks:999, eps:0.000, mu:[1.], std:[0.01], V: 17.17 ±   nan torch.Size([1, 1]), losses (cri:298.3305, act:  0.8451),   84s
# ```
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ```
# 1000 rew:   94.3 ± 0.1 [90.91,96.04], best:  94.51, ticks:108, eps:0.000, mu:[0.556], std:[0.205], V:107.83 ±   nan torch.Size([1, 1]), losses (cri: 25.9878, act: 49.4737),    8s
# ```
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# 500 rew:   95.7 ± 0.1 [93.45,97.20], best:  96.00, ticks:209, eps:0.000, mu:[0.004], std:[0.227], V: 16.72 ± 14.56 torch.Size([235, 1]), losses (cri:  0.0823, act: -0.2978),   15s
# ```
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# 200 rew:   -0.0 ± 0.0 [-0.07,-0.01], best:  -0.02, ticks:999, eps:0.000, mu:[-0.001], std:[0.01], V: -0.00 ±   nan torch.Size([1, 1]), losses (cri:  0.0000, act:  0.0018),   81s
# ```
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
